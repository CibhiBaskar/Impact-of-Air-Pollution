# %% [markdown]
# # CO2 Emission in India (2016-2020)

# %%
import pandas as pd
import matplotlib.pyplot as mp
# %matplotlib notebook

# %%
data = pd.read_csv("Data Sets/Pre Corona Pandemic Datasets/CO2 Level.csv")
df = pd.DataFrame(data)
df.head()
# Out:
#          Year  CO2 emissions      Units
# 0  01-01-2016           2027  Mt of CO2
# 1  01-01-2017           2058  Mt of CO2
# 2  01-01-2018           2162  Mt of CO2
# 3  01-01-2019           2299  Mt of CO2
# 4  01-01-2020           2315  Mt of CO2

# %% [markdown]
# # Data Preprocessing

# %%
df.dtypes
# Out:
# Year             object
# CO2 emissions     int64
# Units            object
# dtype: object

# %%
df['Year'] = pd.to_datetime(df['Year'])
df
# Out:
#         Year  CO2 emissions      Units
# 0 2016-01-01           2027  Mt of CO2
# 1 2017-01-01           2058  Mt of CO2
# 2 2018-01-01           2162  Mt of CO2
# 3 2019-01-01           2299  Mt of CO2
# 4 2020-01-01           2315  Mt of CO2

# %%
df.dtypes
# Out:
# Year             datetime64[ns]
# CO2 emissions             int64
# Units                    object
# dtype: object

# %%
df = df.set_index('Year')
df
# Out:
#             CO2 emissions      Units
# Year
# 2016-01-01           2027  Mt of CO2
# 2017-01-01           2058  Mt of CO2
# 2018-01-01           2162  Mt of CO2
# 2019-01-01           2299  Mt of CO2
# 2020-01-01           2315  Mt of CO2

# %% [markdown]
# # Data Visualization

# %%
y = df['CO2 emissions']
df.plot(kind='line',marker='.',color='teal')
mp.grid(which='both', axis='both',linewidth=0.4)
mp.xlabel('Years',fontsize='large', fontweight='bold')
mp.ylabel('Mt of CO2',fontsize='large', fontweight='bold')
mp.title('TOTAL CO2 EMISSIONS IN INDIA',fontsize='large', fontweight='bold')
for a,b in zip(df.index, y): 
    mp.text(a, b+9, str(b),bbox=dict(facecolor='red', alpha=0.7),color='white',fontsize=9,fontweight='bold')
mp.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
